# %%
# open an image file and display it
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from kerbal import get_json_from_image
import os


directory = "../svg/screenshots"
files = []
for filename in os.listdir(directory):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        file_path = os.path.join(directory, filename)
        files.append(file_path)

print(files)

results = []
for i in range(len(files)):
    result = get_json_from_image(files[i], verbose=True)
    if result is None:
        continue
    result["filename"] = files[i]
    results.append(result)
# Out:
# ['../svg/screenshots\\20240104180651_1.jpg', '../svg/screenshots\\20240104180654_1.jpg', '../svg/screenshots\\20240104180657_1.jpg', '../svg/screenshots\\20240104180659_1.jpg', '../svg/screenshots\\20240104180702_1.jpg', '../svg/screenshots\\20240104180704_1.jpg', '../svg/screenshots\\20240104180718_1.jpg', '../svg/screenshots\\20240104180721_1.jpg', '../svg/screenshots\\20240104180727_1.jpg', '../svg/screenshots\\20240104180729_1.jpg', '../svg/screenshots\\20240104180731_1.jpg', '../svg/screenshots\\20240104180733_1.jpg', '../svg/screenshots\\20240104180736_1.jpg', '../svg/screenshots\\20240104180738_1.jpg', '../svg/screenshots\\20240104180740_1.jpg']
#
#
# Hoan T bsg
# # HEAT SHIELD
#
# Originally designed to be a high end hibachi grill, the HS-
# B1T turned out to be a fantastic little heat shield. What
# you do with it after you land is up to you
#
#
#
# Wi Statistics
#
# Mass
# 0.075t
#
# Max Temp
# 1700 K
#
# *Impact Tolerance
# 20 m/s
#
# *Ablator
# 6.05 t
#
# ...

# %%
import json
with open('results.json', 'w') as f:
    json.dump(results, f, indent=2)

# %%
# write results to file
import json
from importlib import reload
import kerbal
kerbal = reload(kerbal)
dict_to_wiki_table = kerbal.dict_to_wiki_table

# get results from results.json
with open('results.json') as f:
    results = json.load(f)

# omit the "Description" and "filename" properties
results2 = [dict((k, v) for k, v in d.items() if k not in ["Description", "filename"]) for d in results]

print(results)

with open('results.txt', 'w') as f:
    f.write(dict_to_wiki_table(results2[0:6]))
# Out:
# [{'Part Name': 'HS-B1T', 'Name': 'HEAT SHIELD', 'Description': 'Originally designed to be a high-end hibachi grill, the HS-B1T turned out to be a fantastic little heat shield. What you do with it after you land is up to you.', 'Mass': '0.075t', 'Max Temperature': '1700 K', 'Impact Tolerance': '20 m/s', 'Ablator': '6.05 t', 'filename': '../svg/screenshots\\20240104180651_1.jpg'}, {'Part Name': 'H5-125', 'Name': 'HEAT SHIELD', 'Description': 'The team at 0.4.B Demolitions were skeptical working on heat shields, but they soon learned that superheating a part to insane temperatures and not having them explode was almost as much fun as blowing them up. Almost', 'Mass': '0.300t', 'Max Temperature': '1700 K', 'Impact Tolerance': '20 m/s', 'Ablator': 'Go', 'Resources': '50/8', 'filename': '../svg/screenshots\\20240104180654_1.jpg'}, {'Description': 'The HS-250 combines the latest high-tensile alloys combined with a heaping amount of <top-secret heat absorbing ingredient> to ensure your craft
# ...
