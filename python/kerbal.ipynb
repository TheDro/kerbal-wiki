# %%
# open an image file and display it
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import kerbal
import os
import json
import datetime


directory = "./input"
files = kerbal.get_files(directory)

print(files)

results = []
for i in range(len(files)):
    result = kerbal.get_json_from_image(files[i], verbose=True)
    if result is None:
        continue
    result["filename"] = files[i]
    results.append(result)
# Out:
# ['./input\\20240108201211_1.jpg', './input\\20240108201213_1.jpg', './input\\20240108201214_1.jpg', './input\\20240108201217_1.jpg', './input\\20240108201218_1.jpg', './input\\20240108201220_1.jpg', './input\\20240108201222_1.jpg', './input\\20240108201227_1.jpg', './input\\20240108201229_1.jpg', './input\\20240108201230_1.jpg', './input\\20240108201232_1.jpg', './input\\20240108201239_1.jpg', './input\\20240108201241_1.jpg', './input\\20240108201246_1.jpg', './input\\20240108201247_1.jpg', './input\\20240108201249_1.jpg', './input\\20240108201251_1.jpg', './input\\20240108201253_1.jpg', './input\\20240108201256_1.jpg', './input\\20240108201259_1.jpg', './input\\20240108201302_1.jpg', './input\\20240108201303_1.jpg', './input\\20240108201305_1.jpg', './input\\20240108201308_1.jpg', './input\\20240108201311_1.jpg', './input\\20240108201313_1.jpg']
#
#
# Mki "Exelorer” we
# # SINGLE SEAT LANDER CAN
#
# The Nk1 "Explorer* is @ single-seat lander can designed for landing on
# ...

# %%
current_datetime = datetime.datetime.now()
formatted_datetime = current_datetime.strftime("%Y-%m-%dT%H-%M-%S")
output_json = f"output/results_{formatted_datetime}.json"
with open(output_json, 'w') as f:
    json.dump(results, f, indent=2)

# %%
from importlib import reload
kerbal = reload(kerbal)
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

imgs = kerbal.get_cropped_images('./input/20240108201220_1.jpg')
imgs = kerbal.get_cropped_images('./input/20240108201303_1.jpg')
# show image
plt.imshow(imgs[2])
plt.axis('off')
plt.show()

# %%
# write results to file
import json
from importlib import reload
import kerbal
kerbal = reload(kerbal)
dict_to_wiki_table = kerbal.dict_to_wiki_table

# get results from results.json
with open('results1.json') as f:
    results = json.load(f)

# omit the "Description" and "filename" properties
results2 = [dict((k, v) for k, v in d.items() if k not in ["Description", "filename"]) for d in results]

print(results)

with open('results.txt', 'w') as f:
    f.write(dict_to_wiki_table(results2[6:]))
# Out:
# [{'Part Name': 'HS-B1T', 'Name': 'HEAT SHIELD', 'Description': 'Originally designed to be a high-end hibachi grill, the HS-B1T turned out to be a fantastic little heat shield. What you do with it after you land is up to you.', 'Mass': '0.075t', 'Max Temperature': '1700 K', 'Impact Tolerance': '20 m/s', 'Ablator': '6.05 t', 'filename': '../svg/screenshots\\20240104180651_1.jpg'}, {'Part Name': 'H5-125', 'Name': 'HEAT SHIELD', 'Description': 'The team at 0.4.B Demolitions were skeptical working on heat shields, but they soon learned that superheating a part to insane temperatures and not having them explode was almost as much fun as blowing them up. Almost', 'Mass': '0.300t', 'Max Temperature': '1700 K', 'Impact Tolerance': '20 m/s', 'Ablator': 'Go', 'Resources': '50/8', 'filename': '../svg/screenshots\\20240104180654_1.jpg'}, {'Description': 'The HS-250 combines the latest high-tensile alloys combined with a heaping amount of <top-secret heat absorbing ingredient> to ensure your craft
# ...
