# %%
# open an image file and display it
import os
execfile("./env.py")
execfile("./env.local.py")
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# filename = '../svg/images/image935.jpg'
filename = '../svg/images/image995.jpg'

img = mpimg.imread(filename)
# crop the image
img = img[50:950, 470:950]
plt.imshow(img)

# %%
from kerbal import get_json_from_image

result = get_json_from_image('../svg/images/image959.jpg', verbose=True)
# Out:
# GRFH-258 pe
# # GRIDFIN
#
# The GRFN-258 is designed to help booster recovery by
# providing drag and some steering control. C7 insists it was
# not designed as a response to recent competitor WingIt
# Enterprises’ procedural engineering
#
# WiStatiatics
#
# Mass
# 0.320t
#
# Max Temp
# 1000 K
#
# *Impact Tolerance
# 15 m/s
#
# (GHFT):view Lose B reverse
#
# {   'Description': 'The GRFN-258 is designed to help booster recovery by providing drag and some steering control. C7 '
#                    'insists it was not designed as a response to recent competitor WingIt Enterprises’ procedural '
#                    'engineering.',
#     'Name': 'GRIDFIN',
#     'Part Name': 'GRFN-258',
#     'Specifications': {'Impact Tolerance': '15 m/s', 'Mass': '0.320t', 'Max Temperature': '1000 K'}}
