# %%
# open an image file and display it
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from kerbal import get_json_from_image
import os

directory = "../svg/screenshots"
files = []
for filename in os.listdir(directory):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        file_path = os.path.join(directory, filename)
        files.append(file_path)

print(files)

results = []
for i in range(len(files)):
    result = get_json_from_image(files[i], verbose=True)
    result["filename"] = files[i]
    results.append(result)
# Out:
# ['../svg/screenshots\\20240104180651_1.jpg', '../svg/screenshots\\20240104180654_1.jpg', '../svg/screenshots\\20240104180657_1.jpg', '../svg/screenshots\\20240104180659_1.jpg', '../svg/screenshots\\20240104180702_1.jpg', '../svg/screenshots\\20240104180704_1.jpg', '../svg/screenshots\\20240104180718_1.jpg', '../svg/screenshots\\20240104180721_1.jpg', '../svg/screenshots\\20240104180727_1.jpg', '../svg/screenshots\\20240104180729_1.jpg', '../svg/screenshots\\20240104180731_1.jpg', '../svg/screenshots\\20240104180733_1.jpg', '../svg/screenshots\\20240104180736_1.jpg', '../svg/screenshots\\20240104180738_1.jpg', '../svg/screenshots\\20240104180740_1.jpg']
#
#
# Hoan T bsg
# # HEAT SHIELD
#
# Originally designed to be a high end hibachi grill, the HS-
# B1T turned out to be a fantastic little heat shield. What
# you do with it after you land is up to you
#
#
#
# Wi Statistics
#
# Mass
# 0.075t
#
# Max Temp
# 1700 K
#
# *Impact Tolerance
# 20 m/s
#
# *Ablator
# 6.05 t
#
# ...

# %%
# write results to file
import json

with open('results.json', 'w') as f:
    json.dump(results, f, indent=2)

# %%
image_path = "../svg/screenshots/20240104180651_1.jpg"
img = mpimg.imread(image_path)
img0 = img[50:950, 470:950]
img1 = img[50:250, 470:1050]
img2 = img[250:950, 470:740]
img3 = img[250:950, 740:1050]
plt.imshow(img1)

# %%
from pytesseract import pytesseract
import easyocr
import numpy as np

image_path = "../svg/screenshots/20240104180731_1.jpg"
img = mpimg.imread(image_path)
img0 = img[50:950, 470:1020]

print(pytesseract.image_to_string(img1, lang="eng"))
# reader = easyocr.Reader(['en'])
# output2 = reader.readtext(img0)
# print(output2)
# Out:
# WSEL-B1 te
# # RADIATION SURVEY
#
# The WSRL-@1 is designed to collect and process radiation samples
# across a wide spectrum of frequencies, both locally and in deep
# space. It is so sensitive that it can even detect and measure the
# very faint cosmic background radiation signature. But it can’t be
# used to microwave snacks, so don’t try
#
# peetetiattcs # SCIENCE EXPERIMENT
#
# Mass - Experiment: Radiation Observation
# 0.560t + Reports Created: Data
#
# <Data Report Size: 25 KiB
# *Max Temp + Requirements:
#
# 6008 K All situations and locations
#
# «Experiment Duration: 01:08
# *
# Impact Tolerance + Resources Required
#
# 8 m/s «Electric Charge 8.8 U/s
